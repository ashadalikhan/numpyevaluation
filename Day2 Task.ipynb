# %%
import numpy as np

# %%
from PIL import Image

# %%
import matplotlib.pyplot as plt

# %%
I = Image.open('123.jpg')

# %%
I.show()

# %%
plt.imshow(np.asarray(I))
plt.show()

# %%
print (I.size, I.mode, I.format)
# Out:
# (640, 960) RGB JPEG

# %%
print(shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-bd40294c389d> in <module>
# ----> 1 print(shape)
#
# NameError: name 'shape' is not defined

# %%
I1=I.convert('L') # 'L' for gray scale mode
print (I1.mode)
# Out:
# L

# %%
plt.imshow(np.asarray(I1), cmap='gray')
plt.show()

# %%
I1.save('123_gray.jpg')

# %%
plt.imshow(np.asarray(I2), cmap='RGB')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c2f1a915d78f> in <module>
# ----> 1 plt.imshow(np.asarray(I2), cmap='RGB')
#
# NameError: name 'I2' is not defined

# %%
e
